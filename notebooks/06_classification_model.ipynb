# %% [markdown]
# # 06. 직무군 분류 모델 (RQ5)
#
# **담당:** D
#
# ## Validity Guardrail #3 — 순환논리 회피
# - **주 모델:** 직무군 분류 (워크넷 직종코드 / LinkedIn job title 기반 라벨)
# - **보조 모델:** AI 관련 분류 — 키워드 약지도, 한계 명시
#
# ## 직무군 클래스
# Frontend / Backend / Fullstack / Data·AI / DevOps·Cloud / Security / Other IT
#
# ## 모델 후보
# 1. TF-IDF + Logistic Regression
# 2. TF-IDF + LinearSVC
# 3. TF-IDF + Random Forest
# 4. Sentence-BERT + Logistic Regression

# %%
import sys
sys.path.append('..')
from src.modeling.job_classifier import build_tfidf_lr_pipeline, build_tfidf_svm_pipeline, train_and_evaluate
from src.modeling.evaluation import evaluate
from sklearn.model_selection import train_test_split

# %%
# TODO: 라벨 생성 + train/test split

# %%
# TODO: 모델별 학습 + 평가

# %%
# TODO: Confusion Matrix 시각화
