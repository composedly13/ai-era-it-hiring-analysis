# %% [markdown]
# # 01. 빅카인즈 뉴스 수집
#
# **담당:** B
#
# ## 목표
# - 빅카인즈 키워드·기간 분할 내보내기 → `data/raw/news/`
# - 분석 기간: 2021-01 ~ 2026-05 (ChatGPT 전후 비교)
# - 본문 최대 200자 제한 인지 + 다운로드 20,000건/쿼리 제한 대응
#
# ## 체크리스트
# - [ ] 빅카인즈 계정 생성
# - [ ] 키워드별·기간별 분할 쿼리 설계
# - [ ] CSV/XLSX 다운로드 (각 20,000건 이하)
# - [ ] 파일 병합 + 중복 제거
# - [ ] 날짜 컬럼 표준화

# %%
import sys
sys.path.append('..')
from src.collection.bigkinds_news import load_bigkinds_csv, merge_all

# %%
# TODO: 분할 파일 병합
# df_news = merge_all('../data/raw/news')
# print(df_news.shape)

# %%
# TODO: before/after 분기 확인
# from src.analysis.time_series import before_after_comparison
# groups = before_after_comparison(df_news, date_col='발행일')
# print('Before:', len(groups['before']), '/ After:', len(groups['after']))
