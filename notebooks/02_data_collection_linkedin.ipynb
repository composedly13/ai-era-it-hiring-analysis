# %% [markdown]
# # 02. LinkedIn 채용공고 수집 및 필터링
#
# **담당:** C
#
# ## 목표
# - Kaggle `arshkon/linkedin-job-postings` 다운로드 → `data/raw/linkedin/`
# - postings + skills + companies + industries 병합
# - IT 직무군 필터링 (123,000+ → IT 서브셋)
#
# ## 주의
# - 데이터셋이 ChatGPT 출시(2022.11) 이후만 포함 → "AI 이전/이후" 비교 **불가**
# - LinkedIn = **글로벌 단면**으로만 해석
#
# ## 체크리스트
# - [ ] Kaggle 계정 + API 토큰 설정
# - [ ] 파일 다운로드 및 크기 확인
# - [ ] epoch → datetime 변환
# - [ ] IT 직무 필터링 후 규모 확인
# - [ ] processed 저장

# %%
import sys
sys.path.append('..')
from src.collection.linkedin_loader import load_postings, merge_skills, filter_it_jobs

# %%
# TODO: 로드 + 병합
# df_li = load_postings('../data/raw/linkedin')
# df_li = merge_skills(df_li, '../data/raw/linkedin')
# df_li_it = filter_it_jobs(df_li)
# print(df_li_it.shape)
