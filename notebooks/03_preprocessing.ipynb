# %% [markdown]
# # 03. 전처리 및 기술스택 사전 적용
#
# **담당:** D (전원 기여)
#
# ## 목표
# - 3개 데이터소스 공통 정제 (HTML, 특수문자, 중복, 날짜)
# - 한국어(KoNLPy) / 영어(NLTK·spaCy) 언어별 전처리
# - 기술스택 사전으로 동의어 표준화
# - 저장: `data/processed/`

# %%
import sys
sys.path.append('..')
from src.preprocessing.korean_preprocessor import preprocess as ko_preprocess
from src.preprocessing.english_preprocessor import preprocess as en_preprocess
from src.preprocessing.tech_dictionary import normalize, TECH_DICT

# %%
# TODO: 워크넷 전처리
# df_worknet = ...
# df_worknet['tokens'] = df_worknet['text'].apply(ko_preprocess)

# %%
# TODO: 뉴스 전처리
# TODO: LinkedIn 전처리
# TODO: 기술스택 사전 토큰 추출 + 동의어 표준화
