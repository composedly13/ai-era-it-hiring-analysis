# %% [markdown]
# # 07. RQ4 — 담론 vs 현실 비교 (핵심)
#
# **담당:** A · B · D 공동
#
# ## Validity Guardrail #1 — 공정한 비교 축
# - 동일 시점: 2026년 뉴스 vs 2026년 워크넷
# - 비교 단위: 기술스택 사전 토큰 (언어 무관)
# - 뉴스(담론) vs 워크넷(국내 현실) vs LinkedIn(글로벌)
#
# ## 핵심 질문
# > "언론이 강조하는 키워드와 실제 채용에서 요구하는 역량은 얼마나 다른가?"
#
# ## 시각화 목표
# - 뉴스 vs 워크넷 상위 키워드 나란히 비교 막대
# - AI 관련 키워드 뉴스 언급률 vs 워크넷 공고 비율 꺾은선

# %%
import sys
sys.path.append('..')
from src.visualization.comparison_chart import plot_discourse_vs_reality

# %%
# TODO: 동일 시점 데이터 로드

# %%
# TODO: 기술스택 단위 빈도 계산 (뉴스 / 워크넷)

# %%
# TODO: 비교 차트 출력
# plot_discourse_vs_reality(news_freq, worknet_freq, save_path='../outputs/figures/rq4_discourse_vs_reality.png')
