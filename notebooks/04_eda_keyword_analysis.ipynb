# %% [markdown]
# # 04. 탐색적 분석 — 키워드 빈도 · TF-IDF · WordCloud
#
# ## RQ 연결
# - RQ1: 워크넷 상위 빈도 역량
# - RQ2: LinkedIn AI 역량 분포
# - RQ3: 뉴스 연도별 키워드 변화
#
# ## 포함 분석
# 1. 데이터소스별 기술스택 상위 빈도 막대그래프
# 2. 직무군별 TF-IDF 상위 키워드 히트맵
# 3. WordCloud (워크넷, 뉴스 before/after)
# 4. 연도별·월별 AI 키워드 언급률 시계열

# %%
import sys
sys.path.append('..')
from src.analysis.frequency_analysis import token_frequency
from src.analysis.tfidf_analysis import top_terms_per_group
from src.analysis.time_series import monthly_keyword_count, before_after_comparison
from src.visualization.wordcloud_gen import generate_wordcloud

import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # 한글 폰트

# %%
# TODO: RQ1 — 워크넷 빈도 분석

# %%
# TODO: RQ2 — LinkedIn AI 역량

# %%
# TODO: RQ3 — 뉴스 시계열
