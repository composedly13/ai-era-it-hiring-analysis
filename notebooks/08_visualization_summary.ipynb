# %% [markdown]
# # 08. 발표용 시각화 최종 정리
#
# **담당:** D
#
# ## 산출 시각화 목록
# | 파일명 | 내용 | 노트북 |
# |---|---|---|
# | `news_trend_monthly.png` | 연도별 뉴스 기사 수 | 04 |
# | `ai_keyword_trend.png` | AI 키워드 월별 언급률 | 04 |
# | `worknet_top_skills.png` | 워크넷 상위 역량 막대 | 04 |
# | `linkedin_top_skills.png` | LinkedIn 상위 역량 막대 | 04 |
# | `tfidf_heatmap.png` | 직무군별 TF-IDF 히트맵 | 04 |
# | `cooccurrence_network.png` | 기술스택 공기어 네트워크 | 05 |
# | `bertopic_topics.png` | BERTopic 토픽 분포 | 05 |
# | `umap_clusters.png` | UMAP 직무군 산점도 | 05 |
# | `confusion_matrix.png` | 분류 모델 Confusion Matrix | 06 |
# | `rq4_discourse_vs_reality.png` | 담론 vs 현실 비교 (RQ4 핵심) | 07 |

# %%
# 모든 outputs/figures/ 파일 목록 확인
import os
for f in sorted(os.listdir('../outputs/figures')):
    print(f)
