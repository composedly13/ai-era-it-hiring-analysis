# %% [markdown]
# # 00. 워크넷 채용정보 수집
#
# **담당:** A
#
# ## 목표
# - 공공데이터포털 워크넷 API로 IT 채용공고 목록·상세 수집
# - `채용정보URL` 크롤링으로 직무내용 본문 확보 (텍스트/이미지 여부 1일차 검증 필수)
# - 저장: `data/raw/worknet/`
#
# ## 체크리스트
# - [ ] API 키 발급 확인
# - [ ] IT 키워드별 목록 수집 (채용목록 API)
# - [ ] 상세 정보 수집 (callTp=D)
# - [ ] 채용정보URL 1건 열어 텍스트 본문 여부 확인
# - [ ] 크롤링 본문 수집 or 구조화 필드 대체 결정
# - [ ] raw CSV 저장
#
# ## 출처 표시 (논문 필수)
# 한국고용정보원_워크넷 채용정보 채용목록 및 상세정보, 공공데이터포털 #3038225,
# 이용허락 제4유형(출처표시·비상업적·변경금지)

# %%
import os, sys
sys.path.append('..')
from src.collection.worknet_api import collect_all
from src.collection.worknet_crawler import crawl_batch

API_KEY = os.environ.get('WORKNET_API_KEY', 'YOUR_API_KEY_HERE')

# %%
# TODO: API 수집
# df_worknet = collect_all(API_KEY)

# %%
# TODO: URL 크롤링 (텍스트 여부 검증 후 진행)
# df_worknet = crawl_batch(df_worknet)

# %%
# TODO: 저장
# df_worknet.to_csv('../data/raw/worknet/worknet_raw.csv', index=False, encoding='utf-8-sig')
